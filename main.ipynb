# %%
from datetime import date

import pandas as pd
from IPython.display import Markdown

from data import PROGRAMS
from models import AVAILABILITY_TYPES, COUNTRIES, Semester

# %%
display(Markdown(f"## This notebook is run on {date.today()}"))
# Out:
# ## This notebook is run on 2026-04-30

# %%
TARGET_SEMESTER = Semester(starting_year="2026", season="winter")

# %%
programs = pd.DataFrame(
    [
        {
            "name": p.name,
            "university": p.university_name,
            "country": p.country,
            "availability": p.get_availability(TARGET_SEMESTER),
            "application_fee": p.application_fee,
            "window_start": p.get_days_until_window_starts(TARGET_SEMESTER),
            "window_end": p.get_days_until_window_ends(TARGET_SEMESTER),
            "specializations": p.specializations,
        }
        for p in PROGRAMS
    ]
)

# %%
for a in AVAILABILITY_TYPES:
    display(Markdown(f"## {a.upper()}"))
    display(programs[programs["availability"] == a])
# Out:
# ## CLOSED
#                                 name  \
# 0                   Computer Science
# 2                   Computer Science
# 7                   Computer Science
# 14  Computer and Information Science
# 15          Applied Computer Science
# 17      Software Systems Engineering
# 23                 Cognitive Science
# 25                 Cognitive Science
# 28   Neural and Behavioural Sciences
# 29                      Neuroscience
# 30                      Neuroscience
# 32                  Computer Science
# 33                  Computer Science
# 34                  Computer Science
# 35  Computer Science and Engineering
# 38                  Computer Science
# 40                  Computer Science
# 41              Software Engineering
#
#                                            university  country availability  \
# 0                             University of Stuttgart  Germany       closed
# 2                                University of Siegen  Germany       closed
# 7                              Ruhr University Bochum  Germany       closed
# 14                             University of Konstanz  Germany       closed
# 15                           University of Goettingen  Germany       closed
# 17                             RWTH Aachen University  Germany       closed
# 23  Rhineland-Palatinate Technical University of K...  Germany       closed
# 25                  Technical University of Darmstadt  Germany       closed
# 28                            University of Tuebingen  Germany       closed
# 29                            University of Oldenburg  Germany       closed
# 30                               University of Bremen  Germany       closed
# 32                       University of Bari Aldo Moro    Italy       closed
# 33                             University of Camerino    Italy       closed
# 34                                University of Genoa    Italy       closed
# 35                              Politecnico di Milano    Italy       closed
# 38                                 University of Pisa    Italy       closed
# 40                               University of Trento    Italy       closed
# 41                   Free University of Bozen-Bolzano    Italy       closed
#
#     application_fee  window_start  window_end  \
# 0               0.0        -166.0        -105
# 2               0.0        -119.0           0
# 7               NaN        -180.0        -136
# 14              NaN         -43.0         -15
# 15              0.0         -46.0         -15
# 17              0.0        -150.0         -60
# 23             60.0         -66.0           0
# 25              NaN        -150.0         -60
# 28              NaN           NaN         -30
# 29             30.0         -46.0           0
# 30              NaN         -60.0           0
# 32              NaN           NaN         -61
# 33             20.0           NaN         -30
# 34             30.0        -155.0         -41
# 35              NaN        -107.0         -63
# 38             30.0        -150.0         -84
# 40             30.0           NaN         -57
# 41             50.0         -59.0          -2
#
#                                       specializations
# 0   [Autonomous Systems in Computer Science, Servi...
# 2   [Complex and Intelligent Software Systems, Emb...
# 7   [Artificial Intelligence, Cybersecurity, Quant...
# 14  [Algorithmics, Data science, Interactive syste...
# 15  [Applied System Engineering, Bioinformatics, B...
# 17  [Applied Computer Science, Communication, Data...
# 23  [Cognition and Knowledge, Cognitive Neuroscien...
# 25  [Applied Cognitive Science, Artificial Intelli...
# 28  [Brain Imaging and Recording, Cognitive Neuros...
# 29  [Behavioural Neuroscience, Computational Neuro...
# 30  [Computational Neuroscience, Experimental Neur...
# 32    [Artificial Intelligence, Security Engineering]
# 33  [Artificial Intelligence, Business Information...
# 34  [Data Science & Engineering, Software Security...
# 35  [Ambient and data intelligence, Artificial int...
# 38  [Artificial Intelligence, Big Data Technologie...
# 40  [Computer Science and Technologies, ICT Innova...
# 41                                               None
# ## NOT-OPENED
#                                       name                       university  \
# 1                         Computer Science  Technical University of Hamburg
# 9                         Computer Science            University of Marburg
# 18  International Software Systems Science               Bamberg University
# 21                       Cognitive Science           Ruhr University Bochum
# 22                       Cognitive Science         University of Osnabrueck
#
#     country availability  application_fee  window_start  window_end  \
# 1   Germany   not-opened              0.0          32.0          76
# 9   Germany   not-opened             30.0           1.0          61
# 18  Germany   not-opened              0.0          15.0          76
# 21  Germany   not-opened              NaN          32.0          76
# 22  Germany   not-opened             30.0           7.0          46
#
#                                       specializations
# 1   [Computer and Software Engineering, Intelligen...
# 9   [Artificial Intelligence, Cloud Computing, Dat...
# 18  [Communication Systems and Protocols, Distribu...
# 21  [Brain and Behavior, Computation and Artificia...
# 22  [Cognition: (Computational) Neuroscience, Cogn...
# ## OPENED
#                                name                         university  \
# 3                  Computer Science                 University of Bonn
# 4                  Computer Science             University of Hannover
# 6                  Computer Science           University of Regensburg
# 10                 Computer Science             University of Freiburg
# 11   Computer Science International              University of Rostock
# 12                 Computer Science              University of Potsdam
# 19             Software Engineering           University of Hildesheim
# 20                  Web Engineering  Chemnitz University of Technology
# 24                Cognitive Science              University of Potsdam
# 26                Cognitive Systems                  University of Ulm
# 27         Mind, Brain and Behavior              University of Giessen
# 31                Cognitive Science               University of Trento
# 36  Engineering in Computer Science              University of Messina
# 37                 Computer Science                University of Padua
# 39                 Computer Science        Sapienza University of Rome
#
#     country availability  application_fee  window_start  window_end  \
# 3   Germany       opened              0.0         -15.0           1
# 4   Germany       opened             30.0         -15.0          31
# 6   Germany       opened             30.0         -15.0          32
# 10  Germany       opened              0.0         -15.0          31
# 11  Germany       opened             30.0         -29.0          31
# 12  Germany       opened              0.0         -29.0          32
# 19  Germany       opened             30.0         -15.0          61
# 20  Germany       opened             30.0         -29.0          76
# 24  Germany       opened              0.0         -29.0          32
# 26  Germany       opened             30.0         -29.0          15
# 27  Germany       opened             30.0        -150.0          46
# 31    Italy       opened             30.0         -80.0          29
# 36    Italy       opened             30.0         -17.0          10
# 37    Italy       opened             60.0         -59.0           2
# 39    Italy       opened             30.0        -129.0          15
#
#                                       specializations
# 3   [Algorithmics, Graphics/Vision/Audio, Informat...
# 4   [Data Science, Human Centered Computing, Syste...
# 6   [Bioinformatics, Core Computer Science, Human-...
# 10  [Artificial Intelligence, Cyber-Physical Systems]
# 11             [Complex Systems, Information Systems]
# 12  [Algorithms and Foundations, Data and AI, Digi...
# 19  [Advanced Web Development, Model-Based Softwar...
# 20  [Databases, Information Systems, Internet and ...
# 24  [Advanced Natural Language Processing, Cogniti...
# 26  [Interaction, Learning and Memory, Methods, Ge...
# 27  [Current Topics in Cognition and Development, ...
# 31  [Cognitive Neuroscience, Computational and The...
# 36                                               None
# 37                                               None
# 39                                               None
# ## NOT-CLOSED
#                     name                         university  country  \
# 5       Computer Science  Karlsruhe Institute of Technology  Germany
# 8       Computer Science               Paderborn University  Germany
# 13      Computer Science                Saarland University  Germany
# 16  Web and Data Science              University of Koblenz  Germany
#
#    availability  application_fee  window_start  window_end  \
# 5    not-closed              NaN           NaN          46
# 8    not-closed             30.0           NaN          31
# 13   not-closed              NaN           NaN          15
# 16   not-closed             30.0           NaN          46
#
#                                       specializations
# 5   [Algorithm Engineering, Computer Graphics and ...
# 8   [Classical and Quantum Algorithm Design, Compu...
# 13  [Cryptography, Distributed Information and Com...
# 16  [Data Science, Engineering Web and Data-intens...

# %%
display(Markdown("## Applicable Programs Sorted by Days until Window Closes"))

for country in COUNTRIES:
    display(Markdown(f"### {country}"))
    with pd.option_context("display.max_colwidth", None):
        display(
            programs[(programs["window_end"] >= 0) & (programs["country"] == country)]
            .assign(
                specializations=lambda d: d["specializations"].map(
                    lambda x: ", ".join(x) if isinstance(x, (list, tuple, set)) else x
                )
            )
            .sort_values(by=["window_end", "application_fee", "window_start"])
        )

# with pd.option_context("display.max_colwidth", None):
#     display(Markdown("## Applicable Programs' Specialiaztions"))
#     display(
#         programs[programs["window_end"] >= 0].assign(
#             specializations=lambda d: d["specializations"].map(
#                 lambda x: ", ".join(x) if isinstance(x, (list, tuple, set)) else x
#             )
#         )[["name", "university", "specializations"]]
#     )
# Out:
# ## Applicable Programs Sorted by Days until Window Closes
# ### Germany
#                                       name  \
# 2                         Computer Science
# 29                            Neuroscience
# 23                       Cognitive Science
# 30                            Neuroscience
# 3                         Computer Science
# 26                       Cognitive Systems
# 13                        Computer Science
# 10                        Computer Science
# 11          Computer Science International
# 4                         Computer Science
# 8                         Computer Science
# 12                        Computer Science
# 24                       Cognitive Science
# 6                         Computer Science
# 27                Mind, Brain and Behavior
# 22                       Cognitive Science
# 16                    Web and Data Science
# 5                         Computer Science
# 19                    Software Engineering
# 9                         Computer Science
# 18  International Software Systems Science
# 1                         Computer Science
# 20                         Web Engineering
# 21                       Cognitive Science
#
#                                                             university  \
# 2                                                 University of Siegen
# 29                                             University of Oldenburg
# 23  Rhineland-Palatinate Technical University of Kaiserslautern-Landau
# 30                                                University of Bremen
# 3                                                   University of Bonn
# 26                                                   University of Ulm
# 13                                                 Saarland University
# 10                                              University of Freiburg
# 11                                               University of Rostock
# 4                                               University of Hannover
# 8                                                 Paderborn University
# 12                                               University of Potsdam
# 24                                               University of Potsdam
# 6                                             University of Regensburg
# 27                                               University of Giessen
# 22                                            University of Osnabrueck
# 16                                               University of Koblenz
# 5                                    Karlsruhe Institute of Technology
# 19                                            University of Hildesheim
# 9                                                University of Marburg
# 18                                                  Bamberg University
# 1                                      Technical University of Hamburg
# 20                                   Chemnitz University of Technology
# 21                                              Ruhr University Bochum
#
#     country availability  application_fee  window_start  window_end  \
# 2   Germany       closed              0.0        -119.0           0
# 29  Germany       closed             30.0         -46.0           0
# 23  Germany       closed             60.0         -66.0           0
# 30  Germany       closed              NaN         -60.0           0
# 3   Germany       opened              0.0         -15.0           1
# 26  Germany       opened             30.0         -29.0          15
# 13  Germany   not-closed              NaN           NaN          15
# 10  Germany       opened              0.0         -15.0          31
# 11  Germany       opened             30.0         -29.0          31
# 4   Germany       opened             30.0         -15.0          31
# 8   Germany   not-closed             30.0           NaN          31
# 12  Germany       opened              0.0         -29.0          32
# 24  Germany       opened              0.0         -29.0          32
# 6   Germany       opened             30.0         -15.0          32
# 27  Germany       opened             30.0        -150.0          46
# 22  Germany   not-opened             30.0           7.0          46
# 16  Germany   not-closed             30.0           NaN          46
# 5   Germany   not-closed              NaN           NaN          46
# 19  Germany       opened             30.0         -15.0          61
# 9   Germany   not-opened             30.0           1.0          61
# 18  Germany   not-opened              0.0          15.0          76
# 1   Germany   not-opened              0.0          32.0          76
# 20  Germany       opened             30.0         -29.0          76
# 21  Germany   not-opened              NaN          32.0          76
#
#                                                                                                                                                                                                                                                                                                 specializations
# 2                                                                                                                                                                                                                                  Complex and Intelligent Software Systems, Embedded Systems, Visual Computing
# 29                                                                                                                                                                                                                                   Behavioural Neuroscience, Computational Neuroscience, Sensory Neuroscience
# 23                                                                                                                                                                                                           Cognition and Knowledge, Cognitive Neuroscience, Computation, Language and Linguistics, Perception
# 30                                                                                                                                                                                                                                                        Computational Neuroscience, Experimental Neuroscience
# 3                                                                                                                                                                                                            Algorithmics, Graphics/Vision/Audio, Information and Communication Management, Intelligent Systems
# 26                                                                                                                                                                                                    Interaction, Learning and Memory, Methods, General Concepts and Tools, Perception, Planning and Reasoning
# 13                                                                                                                                        Cryptography, Distributed Information and Communications Systems, Image Processing, Language Processing, Multimedia Applications, Program Analysis and Formal Methods
# 10                                                                                                                                                                                                                                                              Artificial Intelligence, Cyber-Physical Systems
# 11                                                                                                                                                                                                                                                                         Complex Systems, Information Systems
# 4                                                                                                                                                                                                                                     Data Science, Human Centered Computing, Systems-oriented Computer Science
# 8                                                                                                                                                              Classical and Quantum Algorithm Design, Computer and Communication Systems, Data Science and Intelligent Systems, Security, Software Engineering
# 12                                                                                                                                                                                                                       Algorithms and Foundations, Data and AI, Digital Health, Security Engineering, Systems
# 24                                                                                                   Advanced Natural Language Processing, Cognition, Cognitive Development, Cognitive Modeling, Cognitive Neuroscience, Evidence Bases for Language Disorders, First Language Acquisition, Language Processing
# 6                                                                                                                                                                                                                           Bioinformatics, Core Computer Science, Human-Centred Computing, Information Systems
# 27                                                                                                                                                         Current Topics in Cognition and Development, Perception and Action, Visual Cognition and Object Perception, Visual Perception of Color and Materials
# 22                                                                                                                   Cognition: (Computational) Neuroscience, Cognition: Artificial Intelligence and Machine Learning, Cognition: Mind, Ethics, and Society, Cognition: Psychology, Language, and Communication
# 16                                                                                                                                                                  Data Science, Engineering Web and Data-intensive Systems, Machine Learning and Data Mining, Network Theory and Dynamic Systems, Web Science
# 5   Algorithm Engineering, Computer Graphics and Geometry Processing, Data Science, Design of Embedded Systems and Computer Architectures, Human-centred Machine Intelligence, Parallel Computing, Robotics and Automation, Software Engineering and Compiler Construction, Telematics, Theoretical Foundations
# 19                                                                                                                            Advanced Web Development, Model-Based Software Engineering, Requirements Engineering for Quality, Software Architectures, Software Engineering, Software Product Line Engineering
# 9                                                                                                                                                                  Artificial Intelligence, Cloud Computing, Databases, Distributed Systems, Graphics Programming, IT Security, Model Checking, Software Design
# 18                                                                                                                                                                      Communication Systems and Protocols, Distributed and Mobile Systems, Service-oriented Architectures, Software Analysis and Verification
# 1                                                                                                                                                                                                                                      Computer and Software Engineering, Intelligence Engineering, Mathematics
# 20                                                                                                                                                                                                                          Databases, Information Systems, Internet and Web Technologies, Software Engineering
# 21                                                                                                                                                                                                                               Brain and Behavior, Computation and Artificial Intelligence, Mind and Language
# ### Italy
#                                name                   university country  \
# 37                 Computer Science          University of Padua   Italy
# 36  Engineering in Computer Science        University of Messina   Italy
# 39                 Computer Science  Sapienza University of Rome   Italy
# 31                Cognitive Science         University of Trento   Italy
#
#    availability  application_fee  window_start  window_end  \
# 37       opened             60.0         -59.0           2
# 36       opened             30.0         -17.0          10
# 39       opened             30.0        -129.0          15
# 31       opened             30.0         -80.0          29
#
#                                                                                                                     specializations
# 37                                                                                                                              NaN
# 36                                                                                                                              NaN
# 39                                                                                                                              NaN
# 31  Cognitive Neuroscience, Computational and Theoretical Modelling of Language and Cognition, fundamental Behavioural Neuroscience
